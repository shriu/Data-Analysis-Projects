# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv('zomato.csv' , encoding='latin-1')
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## Things we do in Data Analysis :
#
# 1. Handle missing values
# 2. Explore numerical values
# 3. Explore categorical values
# 4. Finding relationship between features

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#[features for features in df.columns if df['features'].isnull().sum() >0]

# %%
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head(5)
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df, df_country, on='Country Code' , how='left')
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
final_df.dropna(inplace = True)

# %%
#final_df[(final_df['Restaurant Name'] == 'Natural Ice Cream') or (final_df['Restaurant Name'] == 'Naturals Ice Cream')] 
final_df[(final_df['Restaurant Name'] == 'Naturals Ice Cream') | (final_df['Restaurant Name'] == 'Natural Ice Cream')]
# Out:
#       Restaurant ID     Restaurant Name  Country Code       City  \
# 3013         310143  Naturals Ice Cream             1  New Delhi
# 3944       18349919   Natural Ice Cream             1  New Delhi
# 4354         309844   Natural Ice Cream             1  New Delhi
# 6657         313368  Naturals Ice Cream             1  New Delhi
#
#                                                 Address  \
# 3013      L-8, Outer Circle, Connaught Place, New Delhi
# 3944  G-1, Ground Floor, Opposite Aurobindo Market, ...
# 4354  Ground Floor, JMD Kohinoor Mall, Masjid Moth, ...
# 6657  J-2/10, BK Dutt Market, Rajouri Garden, New Delhi
#
#                                 Locality  \
# 3013                     Connaught Place
# 3944                           Hauz Khas
# 4354  JMD Kohinoor Mall, Greater Kailash
# 6657                      Rajouri Garden
#
#                                    Locality Verbose  Longitude   Latitude  \
# ...

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df['Country'].value_counts()
# Out:
# India             8652
# United States      425
# United Kingdom      80
# South Africa        60
# Brazil              60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Sri Lanka           20
# Singapore           20
# Canada               4
# Name: Country, dtype: int64

# %%
final_df['Country'].value_counts().keys()
# Out:
# Index(['India', 'United States', 'United Kingdom', 'South Africa', 'Brazil',
#        'UAE', 'New Zealand', 'Turkey', 'Australia', 'Phillipines', 'Indonesia',
#        'Qatar', 'Sri Lanka', 'Singapore', 'Canada'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
plt.bar(final_df['Country'].keys() ,final_df['Country'].values, color = 'red')
# Out:
# <BarContainer object of 9542 artists>

# %%
plt.figure(figsize=(20,10))
sns.countplot(final_df['Country'].keys()[:20])
plt.title('Country v/s the Frequency of Ordering', fontweight = 'bold', size=15)
plt.yticks(size= 18)
plt.xticks(size= 18, rotation = 90)
plt.ylabel('Frequency of Ordering',size = 20 )
plt.xlabel('Country', size = 20)
plt.show()
# Out:
# C:\Users\Shriya\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
final_df['Country'].values
# Out:
# array(['Phillipines', 'Phillipines', 'Phillipines', ..., 'Turkey',
#        'Turkey', 'Turkey'], dtype=object)

# %%
plt.figure(figsize=(20,10))
sns.barplot(final_df['Country'].values,final_df['Country'].keys())
plt.title('Country v/s the Frequency of Ordering', fontweight = 'bold', size=15)
plt.yticks(size= 18)
plt.xticks(size= 18, rotation = 90)
plt.ylabel('Frequency of Ordering',size = 20 )
plt.xlabel('Country', size = 20)
plt.show()
# Out:
# C:\Users\Shriya\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Countries that uses zomato the least out of all the countries
plt.subplot(1,2,1)
plt.figure(figsize=(5,5))
plt.bar(list(final_df['Country'].value_counts()[-5:].keys()) , list(final_df['Country'].value_counts()[-5:]), color='red')
plt.show()

#sns barplot : 
plt.subplot(1,2,2)
plt.figure(figsize=(16,5))
sns.barplot(list(final_df['Country'].value_counts()[-5:].keys()) , list(final_df['Country'].value_counts()[-5:]))
plt.title('Top 5 Countries with Least Orderings', fontweight = 'bold', size=15)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Orders',size = 20 )
plt.xlabel('Country', size = 20)
plt.show()
# Out:
# C:\Users\Shriya\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Observations:
# The countries that generates low revenue are Canada, Sri Lanka, Singapore, Qatar, Indonesia

# %%
# Top 5 countries that uses Zomato the most:

plt.figure(figsize=(18,7))
sns.barplot(list(final_df['Country'].value_counts()[0:5].keys()), list(final_df['Country'].value_counts()[0:5]))
sns.set_style('darkgrid')
plt.title('Top 5 nations using Zomato most frequently', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Orders',size = 20 )
plt.xlabel('Country', size = 20)
#plt.show()
# Out:
# C:\Users\Shriya\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Country')

# %% [markdown]
# ### Observations:
# The top 5 countries that generates high revenue are India, United States, United Kingdom, UAE , Brazil

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
k = final_df.groupby(['Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
k
# Out:
#   Rating text  Rating Count
# 0     Average          3734
# 1   Excellent           300
# 2        Good          2096
# 3   Not rated          2148
# 4        Poor           186
# 5   Very Good          1078

# %%
plt.figure(figsize=(18,5))
sns.barplot(x = k['Rating text'], y = k['Rating Count'])
plt.title('Bar plot for the rating text ', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Count',size = 20 )
plt.xlabel('Rating', size = 20)
plt.show()

# %% [markdown]
# ## Observations:
# Zomato has the lowest rating of terrible and has the greatest rating of average. Several of the restaurants were rated as Excellent.

# %%
# Bar plot for the Rating
plt.figure(figsize=(18,7))
sns.barplot(x='Rating text' , y='Rating Count' , data=ratings)
plt.title('Aggregate Rating v/s Rating Count ', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Count',size = 20 )
plt.xlabel('Rating', size = 20)
plt.show()

# %% [markdown]
# ## Observations:

# %%
# Bar plot for the Rating
plt.figure(figsize=(18,7))
sns.barplot(x='Rating text' , y='Rating Count' , data=ratings, hue='Rating color' , palette=['white', 'red', 'orange' , 'yellow', 'green' , 'green'])
plt.title('Aggregate Rating v/s Rating Count ', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Rating Count',size = 20 )
plt.xlabel('Rating Text', size = 20)
plt.show()

# %% [markdown]
# ### Observations :
# ~ Most of the people DID NOT RATE.
#
# ~ Quite a few people rated POOR.
#
# ~ Most ratings were AVERAGE, GOOD AND VERGOOD which is bewteen 2.5-4.4.

# %%
#Name of countries that gave 0 rating 
final_df[final_df['Aggregate rating']==0.0].groupby('Country').size().reset_index().rename(columns={0:'Number of Zero Ratings'})
# Out:
#           Country  Number of Zero Ratings
# 0          Brazil                       5
# 1           India                    2139
# 2  United Kingdom                       1
# 3   United States                       3

# %% [markdown]
# ### Observations:
# Most of the people from India did not rate.

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#Countries that rated 
final_df[final_df['Aggregate rating']!=0.0].groupby(['Country']).size().reset_index().rename(columns={0:'Number of Ratings'})
# Out:
#            Country  Number of Ratings
# 0        Australia                 24
# 1           Brazil                 55
# 2           Canada                  4
# 3            India               6513
# 4        Indonesia                 21
# 5      New Zealand                 40
# 6      Phillipines                 22
# 7            Qatar                 20
# 8        Singapore                 20
# 9     South Africa                 60
# 10       Sri Lanka                 20
# 11          Turkey                 34
# 12             UAE                 60
# 13  United Kingdom                 79
# 14   United States                422

# %%
#Bar chart for the aggregated ratings Vs country 
plt.figure(figsize=(18,7))
sns.barplot(x=final_df['Aggregate rating'] , y=final_df['Country'])
plt.title('Country wise Aggregate Rating', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Country',size = 20 )
plt.xlabel('Aggregate Rating', size = 20)
plt.show()

# %% [markdown]
# ### Observations :
# On an average , ratings from PHILLIPINES, UAE, INDONESIA, NEW ZEALAND, UK, QATAR, SOUTH AFRICA, TURKEY were above 4.

# %%
plt.figure(figsize=(18,7))
explode = [0.1,0]
plt.title('Online Delivery Distribution', fontweight = 'bold', size=20)
plt.pie(final_df['Has Online delivery'].value_counts()/9551*100, labels=final_df['Has Online delivery'].value_counts().index, autopct='%1.1f%%', startangle=180, explode = explode, shadow = True, radius = 1)
plt.yticks(size= 15)
plt.xticks(size= 15);

# %% [markdown]
# ## Observations:
# 25.7% of it was delivered online, while 74.3% were delivered offline.

# %%
#Total number of ratings from all countries above zero
final_df[final_df['Aggregate rating']!=0.0].groupby('Country').size().reset_index().rename(columns={0:'Number of ratings'})
# Out:
#            Country  Number of ratings
# 0        Australia                 24
# 1           Brazil                 55
# 2           Canada                  4
# 3            India               6513
# 4        Indonesia                 21
# 5      New Zealand                 40
# 6      Phillipines                 22
# 7            Qatar                 20
# 8        Singapore                 20
# 9     South Africa                 60
# 10       Sri Lanka                 20
# 11          Turkey                 34
# 12             UAE                 60
# 13  United Kingdom                 79
# 14   United States                422

# %%
#CHALLENGE: which currency is used by which country ?
final_df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index().rename(columns = {0:'Count'})
# Out:
#            Country                Currency  Count
# 0        Australia               Dollar($)     24
# 1           Brazil      Brazilian Real(R$)     60
# 2           Canada               Dollar($)      4
# 3            India      Indian Rupees(Rs.)   8652
# 4        Indonesia  Indonesian Rupiah(IDR)     21
# 5      New Zealand           NewZealand($)     40
# 6      Phillipines        Botswana Pula(P)     22
# 7            Qatar         Qatari Rial(QR)     20
# 8        Singapore               Dollar($)     20
# 9     South Africa                 Rand(R)     60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)     20
# 11          Turkey        Turkish Lira(TL)     34
# 12             UAE      Emirati Diram(AED)     60
# 13  United Kingdom              Pounds(£)     80
# 14   United States               Dollar($)    425

# %%
#CHALLENGE : which countries do have online deliveries?
final_df[final_df['Has Online delivery']=='Yes'].groupby('Country').size().reset_index()
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %%
final_df[['Has Online delivery' , 'Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   425
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# # Observations :
# Online deliveries are available only in some parts of UAE and India .

# %%
# Total Number of ratings from all the countries who rated above 0.0
ratings_above_zero= final_df[final_df['Aggregate rating'] > 0.0]
ratings_above_zero['Aggregate rating'].value_counts()
# Out:
# 3.2    522
# 3.1    519
# 3.4    495
# 3.3    483
# 3.5    480
# 3.0    468
# 3.6    458
# 3.7    427
# 3.8    399
# 2.9    381
# 3.9    332
# 2.8    315
# 4.1    274
# 4.0    266
# 2.7    250
# 4.2    221
# 2.6    191
# 4.3    174
# 4.4    143
# 2.5    110
# 4.5     95
# 2.4     87
# 4.6     78
# 4.9     61
# 2.3     47
# 4.7     41
# 2.2     27
# 4.8     25
# 2.1     15
# 2.0      7
# 1.9      2
# 1.8      1
# Name: Aggregate rating, dtype: int64

# %%
# countplot for countries with ratings above 0 
plt.figure(figsize=(18,7))
sns.countplot(x='Country' ,  data=ratings_above_zero )
plt.xticks(rotation=30)
plt.title('Countries with ratings Above 0', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Count',size = 20 )
plt.xlabel('Rating', size = 20)
plt.show()

# %% [markdown]
# ## Observations:
# India had the most positive reviews on Zomato, according to the data.

# %%
zero_ratings = final_df[final_df['Aggregate rating'] == 0.0]
zero_ratings
# Out:
#       Restaurant ID         Restaurant Name  Country Code            City  \
# 30          6600060          Sandubas Cafí©            30       Brasí_lia
# 58          7305048   Quiosque Chopp Brahma            30  Rio de Janeiro
# 69          6710645        Cantinho da Gula            30      Sí£o Paulo
# 77          6701419           Divino Fogí£o            30      Sí£o Paulo
# 78          6703956             Super Grill            30      Sí£o Paulo
# ...             ...                     ...           ...             ...
# 9109       18277023           Bread & Pasta             1           Noida
# 9110       18313203           Chillies Cafe             1           Noida
# 9111       18254559                Platters             1           Noida
# 9112       18255132               The Grand             1           Noida
# 9351       18273002  Damascena Coffee House           215      Birmingham
#
#                                                 Address  \
# ...

# %%
# countplot for countries with ratings above 0 
plt.figure(figsize=(18,7))
sns.countplot(x='Country' ,  data=zero_ratings )
plt.xticks(rotation=30)
plt.title('Countries that did not Rate', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Count',size = 20 )
plt.xlabel('Rating', size = 20)
plt.show()

# %%
izr = zero_ratings[zero_ratings['Country'] == 'India']
izr
# Out:
#       Restaurant ID        Restaurant Name  Country Code       City  \
# 871            9299  Aggarwal Sweet Corner             1  Faridabad
# 872            9178  Kashyap Vaishno Dhaba             1  Faridabad
# 873        18477319       Total Food Court             1  Faridabad
# 874        18433852          The Chaiwalas             1  Faridabad
# 878        18377449            Aapki Rasoi             1  Faridabad
# ...             ...                    ...           ...        ...
# 9103       18428504       The Hangout-Deli             1      Noida
# 9109       18277023          Bread & Pasta             1      Noida
# 9110       18313203          Chillies Cafe             1      Noida
# 9111       18254559               Platters             1      Noida
# 9112       18255132              The Grand             1      Noida
#
#                                                 Address  \
# 871   Badarpur Border Chowk Post, Badarpur Border, F...
# ...

# %%
izr.groupby(['Restaurant Name']).size().reset_index()
# Out:
#                Restaurant Name  0
# 0                 Let's Burrrp  1
# 1                 #InstaFreeze  1
# 2                     #hashtag  1
# 3                      13 Cafe  1
# 4       17 Degree Food Service  1
# ...                        ... ..
# 1933                   Zawlbuk  1
# 1934  Zayka chicken restaurant  1
# 1935                   Zombiez  1
# 1936               deliKitchen  1
# 1937                  iKitchen  1
#
# [1938 rows x 2 columns]

# %%
#The number of aggregated ratings given by each city from India:
final_df[final_df['Country']=='India'].groupby(['Aggregate rating','City']).size().reset_index().rename(columns={0:'Number of Ratings'})
# Out:
#      Aggregate rating       City  Number of Ratings
# 0                 0.0  Faridabad                100
# 1                 0.0  Ghaziabad                  2
# 2                 0.0    Gurgaon                228
# 3                 0.0  New Delhi               1425
# 4                 0.0      Noida                384
# ..                ...        ...                ...
# 458               4.9    Lucknow                  1
# 459               4.9     Mumbai                  1
# 460               4.9     Nagpur                  1
# 461               4.9  New Delhi                  3
# 462               4.9      Vizag                  1
#
# [463 rows x 3 columns]

# %%
#India ratings
india_ratings = final_df[final_df['Country'] == 'India']
india_ratings.head(5)
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
india_ratings['Aggregate rating'].value_counts()
# Out:
# 0.0    2139
# 3.1     511
# 3.2     510
# 3.4     477
# 3.3     472
# 3.0     465
# 3.5     454
# 3.6     411
# 2.9     380
# 3.7     363
# 3.8     336
# 2.8     314
# 3.9     283
# 2.7     250
# 4.0     193
# 2.6     190
# 4.1     185
# 4.2     140
# 2.5     109
# 4.3     100
# 2.4      83
# 4.4      74
# 2.3      46
# 4.5      37
# 4.6      35
# 2.2      26
# 4.9      19
# 4.7      16
# 2.1      15
# 4.8       9
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
india_ratings.shape
# Out:
# (8652, 22)

# %%
#creating a barplot for the aggregate rating from India
plt.figure(figsize=(18,7))
sns.barplot(list(india_ratings['Aggregate rating'].value_counts().keys()) ,list(india_ratings['Aggregate rating'].value_counts()))
plt.title('Aggregate Ratings by India', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.ylabel('Count',size = 20 )
plt.xlabel('Rating', size = 20)
plt.show()
# Out:
# C:\Users\Shriya\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Observations:
# There were 2139 non-voters. The majority of scores ranged from 3.0 to 3.6.

# %%
# Total votes from each city in India
india_ratings_voted=  india_ratings[india_ratings['Aggregate rating'] > 0.0]
india_ratings_voted
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
plt.figure(figsize=(18,10))
sns.barplot(list(india_ratings_voted['City'].value_counts()) ,list(india_ratings_voted['City'].value_counts().keys()))
plt.title('Most Voted Cities in India', fontweight = 'bold', size=20)
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.show()
# Out:
# C:\Users\Shriya\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Observations :
#  Top 5 cities that voted mostly :
#  New Delhi , Gurgaon, Noida, Faridabad, Ghaziabad

# %%
plt.figure(figsize=(18,7))
sns.countplot(y=india_ratings_voted['Cuisines'], order = india_ratings_voted['Cuisines'].value_counts().iloc[:10].index, palette = 'hls')
plt.xlabel('No of matches',fontsize=12)
plt.ylabel('Venue',fontsize=12)
plt.title('Aggregate Ratings by India', fontweight = 'bold', size=20)
plt.yticks(size= 20)
plt.xticks(size= 20)
plt.ylabel('Cusinies',size = 20 )
plt.xlabel('Most Popular Cusinies in India', size = 20)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# ## Observations:
#
# In India, North Indian cuisine received the most votes.

# %%
Delhi = final_df[(final_df.City == 'New Delhi')]
plt.figure(figsize=(18,7))
sns.barplot(x=Delhi.Locality.value_counts().head(10), y=Delhi.Locality.value_counts().head(10).index, palette = 'hls')
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.xlabel('Number of Restraunts', size = 20)
plt.ylabel(None);
plt.xlabel('Number of Resturants')
plt.title('Resturants Listing on Zomato from New Delhi', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# connaught Place has the highest number of restraunts in Delhi.

# %%
india_ratings_voted.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#Most voted cuisines 
india_ratings_voted[['Cuisines']].groupby('Cuisines').size().reset_index()
# Out:
#                                                Cuisines  0
# 0                                               Afghani  1
# 1                                              American  4
# 2                    American, Asian, European, Seafood  1
# 3     American, Asian, North Indian, Mexican, South ...  1
# 4                        American, British, Continental  1
# ...                                                 ... ..
# 1282                                 Tibetan, Fast Food  1
# 1283                                  Tibetan, Nepalese  2
# 1284                                            Turkish  2
# 1285             Turkish, Mediterranean, Middle Eastern  1
# 1286                                         Vietnamese  1
#
# [1287 rows x 2 columns]

# %%
Delhi.head(3)
# Out:
#       Restaurant ID  Restaurant Name  Country Code       City  \
# 2560       18287358       Food Cloud             1  New Delhi
# 2561       18216944        Burger.in             1  New Delhi
# 2562         313333  Days of the Raj             1  New Delhi
#
#                                                 Address    Locality  \
# 2560                              Aaya Nagar, New Delhi  Aaya Nagar
# 2561        84, Near Honda Showroom, Adchini, New Delhi     Adchini
# 2562  81/3, 1st Floor, Qutub Residency, Adchini, New...     Adchini
#
#            Locality Verbose  Longitude   Latitude  \
# 2560  Aaya Nagar, New Delhi   0.000000   0.000000
# 2561     Adchini, New Delhi  77.196923  28.535382
# 2562     Adchini, New Delhi  77.197475  28.535493
#
#                                 Cuisines  ...  Has Table booking  \
# 2560                      Cuisine Varies  ...                 No
# 2561                           Fast Food  ...                 No
# ...

# %%
# I achieve this by the following steps

## Fetching the resturants having 'Excellent' and 'Very Good' rating
cp = Delhi[(Delhi.Locality.isin(['Connaught Place'])) & (Delhi['Rating text'].isin(['Excellent','Very Good']))]

cp = cp.Cuisines.value_counts().reset_index()

## Extracing all the cuisens in a single list
cuisien = []
for x in cp['index']: 
  cuisien.append(x)

# cuisien = '[%s]'%', '.join(map(str, cuisien))
cuisien
# Out:
# ['North Indian, Chinese, Italian, Continental',
#  'Japanese',
#  'South Indian',
#  'North Indian, Chinese',
#  'North Indian, Italian, Asian, American',
#  'Healthy Food, Continental, Italian',
#  'Asian, North Indian',
#  'North Indian, Afghani, Mughlai',
#  'North Indian',
#  'North Indian, Chinese, Italian, American, Middle Eastern',
#  'Chinese',
#  'North Indian, Chinese, Continental, Italian',
#  'Continental, Mexican, Burger, American, Pizza, Tex-Mex',
#  'North Indian, Continental',
#  'Continental, North Indian, Chinese, Mediterranean',
#  'North Indian, Mediterranean, Asian, Fast Food',
#  'Biryani, Hyderabadi',
#  'Bakery, Desserts, Fast Food',
#  'Cafe',
#  'Biryani, North Indian, Hyderabadi',
#  'Continental, American, Asian, North Indian',
#  'North Indian, European, Asian, Mediterranean',
#  'Continental, Mediterranean, Italian, North Indian',
#  'Continental, Italian, Asian, Indian',
#  'Fast Food, American, Burger',
#  'North Indian, European',
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
plt.figure(figsize = (18,7))
comment_words = ''
stopwords = set(STOPWORDS)
# iterate through the csv file
for val in cuisien:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    #for i in range(len(tokens)):
        #tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = 'b', edgecolor='g')
plt.title('Resturants cuisien -  Top Resturants')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

# %% [markdown]
# ## Observations:
# The following cuisine appears to be doing well for top-rated restaurants.
#
# North Indian, Continental, Italian, Chinese.

# %%
#Places in Delhi that provides online/offline services:
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(15,6))
ax = sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.yticks(size = 15)
plt.xticks(size = 15)
plt.ylabel('Locality',size = 20)
plt.xlabel('Count',size = 20)
plt.title('Resturants Online Delivery', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# Shahdara and Connaught Place had no online delivery at all, whereas Malviya Nagar had the most online deliveries.

# %%
Delhi['Locality'].value_counts()[:10]
# Out:
# Connaught Place        122
# Rajouri Garden          99
# Shahdara                87
# Defence Colony          86
# Pitampura               85
# Mayur Vihar Phase 1     84
# Malviya Nagar           84
# Rajinder Nagar          81
# Safdarjung              80
# Satyaniketan            79
# Name: Locality, dtype: int64

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.countplot(x='Locality' , hue = 'Rating text', data = Delhi[Delhi['Locality']=='Connaught Place'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)

plt.subplot(2,2,2)
sns.countplot(x='Locality' , hue = 'Rating text', data = Delhi[Delhi['Locality']=='Rajouri Garden'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)

plt.subplot(2,2,3)
sns.countplot(x='Locality' , hue = 'Rating text', data = Delhi[Delhi['Locality']=='Shahdara'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)

plt.subplot(2,2,4)
sns.countplot(x='Locality' , hue = 'Rating text', data = Delhi[Delhi['Locality']=='Defence Colony'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Observations:
# Connaught Place, Rajouri Garden, where they obtained a Good rating, Shahdara, where the majority did not rate, and Defence Colony, where ratings were ordinary.
#
#
# #The restaurants that didn't offer numerous online deliveries didn't receive any ratings in Shahdara, but they did in Connaught Place, Rajouri Garden where they received a Good rating and Mayur Vihar recieved an average rating the most .

# %%
not_voted = Delhi[Delhi['Rating text']=='Not rated'].groupby(['Locality']).size().sort_values(ascending  = False).reset_index().rename(columns = {0: 'count'})[:20]
not_voted
# Out:
#                Locality  count
# 0             Najafgarh     59
# 1                 Palam     48
# 2              Shahdara     46
# 3    Vasundhara Enclave     45
# 4       Mukherjee Nagar     44
# 5            Mahipalpur     44
# 6               Nangloi     41
# 7         Subhash Nagar     33
# 8           Tilak Nagar     33
# 9               MG Road     32
# 10        Krishna Nagar     30
# 11      East of Kailash     30
# 12              Naraina     28
# 13  Mayur Vihar Phase 1     27
# 14       Dilshad Garden     25
# 15         Sainik Farms     25
# 16          Uttam Nagar     24
# 17       Lajpat Nagar 1     23
# 18            R K Puram     22
# 19             Jangpura     22

# %%
not_voted.Locality.count()
# Out:
# 20

# %%
plt.figure(figsize=(18,7))
sns.countplot(y='Locality', data = not_voted)
#sns.barplot(list(not_voted['Locality'].value_counts().keys()), list(not_voted['Locality'].value_counts()))
plt.title("Restaurant reviews where the majority Restaurants did not recieved Votes", fontweight = 'bold', size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)
#list(final_df['Country'].value_counts()[-5:].keys()) , list(final_df['Country'].value_counts()[-5:])
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Observations:
# The areas of Delhi with the highest concentration of restaurants offering online delivery received good and average ratings in Malviya Nagar, good ratings in Connaught Place, Rajouri Garden and an average rating in Defence Colony .

# %%
Delhi.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#plt.figure(figsize = (18,7))
#ax = sns.barplot(x='Locality', y='Aggregate rating' , data = Delhi)
#sns.barplot(list(Delhi['Locality'].value_counts().keys()), list(Delhi['Aggregate rating'].value_counts()))
#ax2 = ax.twinx()
#sns.barplot(list(Delhi['Locality'].value_counts()[:10].keys()), list(Delhi['Price range'].value_counts()[:10].keys()))
#sns.lineplot(Delhi['Locality'], Delhi['Price range'], color = 'red')

# %%
plt.figure(figsize=(18,7))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=Delhi)

plt.xlabel("Average Cost for two",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.title('Rating vs Cost of Two', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations :
# Rating has nothing got to do with Price Range. In contrast, some of the tastiest restaurants are also some of the least expensive.

# %%
Delhi[Delhi['Rating text'].isin(['Excellent'])]
# Out:
#       Restaurant ID                       Restaurant Name  Country Code  \
# 2904         303642          Kuremal Mohan Lal Kulfi Wale             1
# 3012       18418277                           MOB Brewpub             1
# 3013         310143                    Naturals Ice Cream             1
# 3014       18357940              Zabardast Indian Kitchen             1
# 3310       18161577                         Spezia Bistro             1
# 3601           2004             Indian Accent - The Manor             1
# 3658       18400736                           Owl is Well             1
# 3732       18241869                                Tashan             1
# 3944       18349919                     Natural Ice Cream             1
# 3981         307931                            Coast Cafe             1
# 4206       18421049                   Midnight Hunger Hub             1
# 4298       18345728                        Masala Library             1
# ...

# %%
Highly_rated = Delhi[Delhi['Rating text'].isin(['Excellent','Very Good'])]

# %%
#location of highly rated restraunts in Delhi:
plt.figure(figsize=(18,5))
sns.countplot(x="Locality", data=Highly_rated)

plt.xlabel("Locality",size = 20)
plt.ylabel("Count",size = 20)
plt.xticks(size = 11, rotation = 90)
plt.yticks(size = 11)
plt.title('Location of highly rated restraunts in Delhi', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations :
# Rajouri Garden and Connaught Place in Delhi are home to some of the city's best restaurants.

# %%
Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') | (Highly_rated['Locality'] == 'Connaught Place')]
# Out:
#       Restaurant ID                       Restaurant Name  Country Code  \
# 3012       18418277                           MOB Brewpub             1
# 3013         310143                    Naturals Ice Cream             1
# 3014       18357940              Zabardast Indian Kitchen             1
# 3092       18241537                           38 Barracks             1
# 3093         309478                        Ambrosia Bliss             1
# 3094           7713                             Ardor 2.1             1
# 3095         301489                       Barbeque Nation             1
# 3096       18219558                      Bikkgane Biryani             1
# 3097       18216915                         Biryani Blues             1
# 3098         306913                               Caffe 9             1
# 3099         307036                        Excuse Me Boss             1
# 3100             67                               Fa Yian             1
# ...

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.countplot(x="Cuisines", data=Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') | (Highly_rated['Locality'] == 'Connaught Place')])
plt.xlabel("Cuisine",size = 20)
plt.ylabel("Count",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Cuisines served in the Highly Rated Restraunts in Delhi', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# In Rajouri Garden, Connaught Place, the restaurants with the highest ratings primarily served North Indian food and ice cream.

# %%
best_delhi = Delhi[Delhi['Rating text'].isin(['Excellent'])]
best_delhi['Restaurant Name'].unique()
# Out:
# array(['Kuremal Mohan Lal Kulfi Wale', 'MOB Brewpub',
#        'Naturals Ice Cream', 'Zabardast Indian Kitchen', 'Spezia Bistro',
#        'Indian Accent - The Manor', 'Owl is Well', 'Tashan',
#        'Natural Ice Cream', 'Coast Cafe', 'Midnight Hunger Hub',
#        'Masala Library', 'Zaffran', 'Big Chill', 'Cafe Lota',
#        'Food Scouts', 'Neung Roi - Radisson Blu Plaza Delhi',
#        'Band Baaja Baaraat', 'Kopper Kadai', 'Qubitos - The Terrace Cafe',
#        'The California Boulevard', 'Echoes Satyaniketan', 'Pa Pa Ya',
#        'Greenr Cafe', 'Cafeteria & Co.'], dtype=object)

# %%
best_delhi = Delhi[Delhi['Rating text'].isin(['Excellent'])]
plt.figure(figsize=(18,5))
sns.countplot(x=best_delhi['Restaurant Name'].values , palette = 'hls')
plt.xticks(size= 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Best Rated Restaurants in Delhi', size = 20, fontweight = 'bold')
plt.xlabel('Restaurants', size = 20)
plt.ylabel(None);
#plt.xlabel('Restaurants', fontweight = 'bold', size = 20);

# %%
vg_delhi = Delhi[Delhi['Rating text'].isin(['Very Good'])]
plt.figure(figsize=(8,50))
sns.countplot(y=vg_delhi['Restaurant Name'].values , palette = 'hls')
plt.xticks(size= 15)
plt.yticks(size = 10)
plt.title('Restaurants Rated Very Good in Delhi', size = 20, fontweight = 'bold')
plt.ylabel('Restaurants', size = 20)
plt.xlabel(None);

# %%
natural_ic_location = best_delhi[(best_delhi['Restaurant Name'] == 'Naturals Ice Cream') | (best_delhi['Restaurant Name'] == 'Natural Ice Cream')]
plt.figure(figsize=(18,5))
sns.countplot(x=natural_ic_location['Locality'].values , palette = 'hls')
plt.xticks(size= 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Location of all the Natural Ice Cream', size = 20, fontweight = 'bold')
plt.xlabel('Restaurants', size = 20)
plt.ylabel(None);

# %%
types = {
    "Breakfast and Coffee" : ["Cafe Coffee Day", "Starbucks", "Barista", "Costa Coffee", "Chaayos", "Dunkin' Donuts"],
    "American": ["Domino's Pizza", "McDonald's", "Burger King", "Subway", "Dunkin' Donuts", "Pizza Hut"],
    "Ice Creams and Shakes": ["Keventers", "Giani", "Giani's", "Starbucks", "Baskin Robbins", "Nirula's Ice Cream"]
}

breakfast = Delhi[Delhi['Restaurant Name'].isin(types['Breakfast and Coffee'])]
american = Delhi[Delhi['Restaurant Name'].isin(types['American'])]
ice_cream = Delhi[Delhi['Restaurant Name'].isin(types['Ice Creams and Shakes'])]

# %%
breakfast = breakfast[['Restaurant Name','Aggregate rating']].groupby('Restaurant Name').mean().reset_index().sort_values('Aggregate rating',ascending=False)
breakfast
# Out:
#    Restaurant Name  Aggregate rating
# 2          Chaayos          3.812500
# 5        Starbucks          3.750000
# 3     Costa Coffee          3.450000
# 0          Barista          3.325000
# 4   Dunkin' Donuts          3.300000
# 1  Cafe Coffee Day          2.573684

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=breakfast, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Breakfast Restraunts', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# In Delhi, Chaayos and Starbucks received the top ratings from customers for a cafe.

# %%
american = american[['Restaurant Name','Aggregate rating']].groupby('Restaurant Name').mean().reset_index().sort_values('Aggregate rating',ascending=False)
american
# Out:
#   Restaurant Name  Aggregate rating
# 0     Burger King          3.477778
# 3      McDonald's          3.445455
# 2  Dunkin' Donuts          3.300000
# 4       Pizza Hut          3.158333
# 5          Subway          3.047368
# 1  Domino's Pizza          2.794545

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=american, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Fast-Food Restraunts', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# Most people preferred and gave Burger King and McDonald's the highest ratings for fast food.

# %%
ice_cream = ice_cream[['Restaurant Name','Aggregate rating']].groupby('Restaurant Name').mean().reset_index().sort_values('Aggregate rating',ascending=False)
ice_cream
# Out:
#       Restaurant Name  Aggregate rating
# 5           Starbucks          3.750000
# 2             Giani's          3.011765
# 3           Keventers          2.983333
# 0      Baskin Robbins          2.769231
# 1               Giani          2.675000
# 4  Nirula's Ice Cream          2.400000

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=ice_cream, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Ice Cream Parlours', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# The folks who live close to Delhi enjoy Starbucks the most and give it the highest overall rating.

# %%
plt.figure(figsize=(25,25))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

plt.subplot(3,3,1)
sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=breakfast, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Breakfast Restraunts', fontweight = 'bold', size = 20);

plt.subplot(3,3,2)
sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=american, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Fast-Food Restraunts', fontweight = 'bold', size = 20);

plt.subplot(3,3,3)
sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=ice_cream, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Ice Cream Parlours', fontweight = 'bold', size = 20);

# %%
gurgaon = final_df[final_df['City'] == 'Gurgaon']
gurgaon
# Out:
#       Restaurant ID       Restaurant Name  Country Code     City  \
# 1161       18396451                 K Lab             1  Gurgaon
# 1162       18237941         Pind Balluchi             1  Gurgaon
# 1163           2787          Punjab Grill             1  Gurgaon
# 1164           3431                Zambar             1  Gurgaon
# 1165         303699          Cakes & More             1  Gurgaon
# ...             ...                   ...           ...      ...
# 2274           6769                 Iroha             1  Gurgaon
# 2275       18441791  Chaudhary Burfi Wala             1  Gurgaon
# 2276           1454      Curry 'n' Phulka             1  Gurgaon
# 2277           6775            Wah Ji Wah             1  Gurgaon
# 2278         306043           Woods Spice             1  Gurgaon
#
#                                                 Address  \
# 1161  Shop GF-18, ILD Trade Centre, Sector 47, Near ...
# 1162  112/112-A, 1st Floor, ILD Trade Centre, Near S...
# ...

# %%
gurgaon.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
plt.figure(figsize=(18,7))
sns.barplot(x=gurgaon.Locality.value_counts().head(10), y=gurgaon.Locality.value_counts().head(10).index, palette = 'hls')
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.xlabel('Number of Restraunts', size = 20)
plt.ylabel(None);
plt.xlabel('Number of Resturants')
plt.title('Resturants Listing on Zomato from Gurgaon', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
# On Zomato, DLF Phase 3 has the most eateries from Gurgaon.

# %%
# restaurants in Gurgaon that have good and excellent ratings:
gurgaon_best = gurgaon[((gurgaon['Locality']=='DLF Phase 3') | (gurgaon['Locality']=='Sector 56') | (gurgaon['Locality']=='Sector 14') | (gurgaon['Locality']=='Palam Vihar'))   & (gurgaon['Rating text'].isin(['Excellent','Very Good']))]
gurgaon_best
#Delhi[(Delhi.Locality.isin(['Connaught Place'])) & (Delhi['Rating text'].isin(['Excellent','Very Good']))]
# Out:
#       Restaurant ID    Restaurant Name  Country Code     City  \
# 1381       18384115        Caterspoint             1  Gurgaon
# 1399       18451182  Coldpress Company             1  Gurgaon
# 1400       18384142      Crudo Juicery             1  Gurgaon
# 1401       18241498          First Eat             1  Gurgaon
# 1402       18265384                Zoe             1  Gurgaon
#
#                                       Address     Locality  \
# 1381            S-27/11, DLF Phase 3, Gurgaon  DLF Phase 3
# 1399              U79/12 DLF Phase 3, Gurgaon  DLF Phase 3
# 1400                     DLF Phase 3, Gurgaon  DLF Phase 3
# 1401                     DLF Phase 3, Gurgaon  DLF Phase 3
# 1402  T-24, Cyber Green, DLF Phase 3, Gurgaon  DLF Phase 3
#
#           Locality Verbose  Longitude   Latitude  \
# 1381  DLF Phase 3, Gurgaon  77.103974  28.487264
# 1399  DLF Phase 3, Gurgaon  77.093211  28.489834
# 1400  DLF Phase 3, Gurgaon  77.104915  28.487150
# ...

# %%
plt.figure(figsize=(18,7))
sns.barplot(x=gurgaon.Cuisines.value_counts().head(10), y=gurgaon.Cuisines.value_counts().head(10).index, palette = 'hls')
plt.yticks(size= 15)
plt.xticks(size= 15)
plt.xlabel('Number of Restaurants', size = 20)
plt.ylabel(None);
#plt.xlabel('Number of Resturants')
plt.title('Popular Cuisines in Gurgaon', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
#
# In Gurgaon, North Indian cuisine is the most popular.

# %%
plt.figure(figsize=(18,7))
sns.countplot(x=gurgaon_best['Restaurant Name'].values , palette = 'hls')
plt.xticks(size= 15)
plt.yticks(size = 15)
plt.title('Best Restaurants in DLF Phase 3, Gurgaon', size = 20, fontweight = 'bold')
plt.xlabel('Restaurants', size = 20)
plt.ylabel(None);
#plt.xlabel('Restaurants', fontweight = 'bold', size = 20);

# %%
# cuisines popular in dlf phase 3:
gurgaon_best['Cuisines'].value_counts()
# Out:
# Healthy Food, Juices, Salad, Italian, Continental    1
# Juices, Beverages, Healthy Food                      1
# Healthy Food, North Indian, Continental              1
# Beverages, Salad, Beverages                          1
# Mexican, American, Healthy Food                      1
# Name: Cuisines, dtype: int64

# %%
plt.figure(figsize=(18,7))
sns.barplot(x=gurgaon_best.Cuisines.value_counts().head(10), y=gurgaon_best.Cuisines.value_counts().head(10).index, palette = 'hls')
plt.yticks(size= 18)
plt.xticks(size= 18)
plt.xlabel('Number of Restaurants', size = 20)
#plt.ylabel(size = 15);
#plt.xlabel('Number of Resturants')
plt.title('Popular Cuisines in DLF Phase 3, Gurgaon', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observation:
# The most well-liked cuisines in the Gurgaon area include north Indian, Chinese, café, and Mughlai.

# %%
#Places in Delhi that provides online/offline services:
top_locality = gurgaon.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
ax = sns.countplot(y= "Locality", hue="Has Online delivery", data=gurgaon[gurgaon.Locality.isin(top_locality.index)])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.ylabel('Locality', size = 15)
plt.xlabel('Count', size = 15)
plt.title('Resturants Online Delivery', fontsize = 20, fontweight = 'bold');

# %% [markdown]
# ## Observations:
# While Palam Vihar has the least amount of online delivery service, DLF Phase 3 has the most.

# %%
plt.figure(figsize=(20,11))
plt.subplot(2,2,1)
plt.title('Ratings of the Top Restaurants in Gurgaon', fontweight = 'bold', size = 20)
sns.countplot(x='Locality' , hue = 'Rating text', data = gurgaon[gurgaon['Locality']=='DLF Phase 3'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)

plt.subplot(2,2,2)
sns.countplot(x='Locality' , hue = 'Rating text', data = gurgaon[gurgaon['Locality']=='Sector 56'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)

plt.subplot(2,2,3)
sns.countplot(x='Locality' , hue = 'Rating text', data = gurgaon[gurgaon['Locality']=='Sector 14'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)

plt.subplot(2,2,4)
sns.countplot(x='Locality' , hue = 'Rating text', data = gurgaon[gurgaon['Locality']=='Palam Vihar'])
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel('Locality',size = 20)
plt.ylabel('Count',size = 20)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Observations:
# The bulk of restaurants in DLF Phase 3, Sector 56, and Sector 14 have mediocre ratings, however few individuals have reviewed eateries in Palam Vihar.

# %%
types = {
    "Breakfast and Coffee" : ["Cafe Coffee Day", "Starbucks", "Barista", "Costa Coffee", "Chaayos", "Dunkin' Donuts"],
    "American": ["Domino's Pizza", "McDonald's", "Burger King", "Subway", "Dunkin' Donuts", "Pizza Hut"],
    "Ice Creams and Shakes": ["Keventers", "Giani", "Giani's", "Starbucks", "Baskin Robbins", "Nirula's Ice Cream"]
}

breakfast = gurgaon[gurgaon['Restaurant Name'].isin(types['Breakfast and Coffee'])]
american = gurgaon[gurgaon['Restaurant Name'].isin(types['American'])]
ice_cream = gurgaon[gurgaon['Restaurant Name'].isin(types['Ice Creams and Shakes'])]

# %%
breakfast = breakfast[['Restaurant Name','Aggregate rating']].groupby('Restaurant Name').mean().reset_index().sort_values('Aggregate rating',ascending=False)
breakfast
# Out:
#    Restaurant Name  Aggregate rating
# 5        Starbucks          3.683333
# 4   Dunkin' Donuts          3.566667
# 2          Chaayos          3.040000
# 0          Barista          2.750000
# 1  Cafe Coffee Day          2.463636
# 3     Costa Coffee          0.660000

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=breakfast, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Breakfast Restraunts', fontweight = 'bold', size = 20);

# %%
american = american[['Restaurant Name','Aggregate rating']].groupby('Restaurant Name').mean().reset_index().sort_values('Aggregate rating',ascending=False)
american
# Out:
#   Restaurant Name  Aggregate rating
# 2  Dunkin' Donuts          3.566667
# 0     Burger King          3.200000
# 3      McDonald's          3.116667
# 5          Subway          2.963636
# 4       Pizza Hut          2.800000
# 1  Domino's Pizza          2.555556

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=american, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Fast-Food Restraunts', fontweight = 'bold', size = 20);

# %%
ice_cream = ice_cream[['Restaurant Name','Aggregate rating']].groupby('Restaurant Name').mean().reset_index().sort_values('Aggregate rating',ascending=False)
ice_cream
# Out:
#   Restaurant Name  Aggregate rating
# 4       Starbucks          3.683333
# 1           Giani          3.400000
# 3       Keventers          3.100000
# 2         Giani's          2.266667
# 0  Baskin Robbins          1.033333

# %%
plt.figure(figsize=(20,7))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=ice_cream, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Ice Cream Parlours', fontweight = 'bold', size = 20);

# %%
plt.figure(figsize=(25,25))
#Highly_rated[(Highly_rated['Locality'] == 'Rajouri Garden') or (Highly_rated['Locality'] == 'Connaught Place')]

plt.subplot(3,3,1)
sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=breakfast, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Breakfast Restaurants', fontweight = 'bold', size = 20);

plt.subplot(3,3,2)
sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=american, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Fast-Food Restaurants', fontweight = 'bold', size = 20);

plt.subplot(3,3,3)
sns.barplot(x="Restaurant Name",y = 'Aggregate rating', data=ice_cream, palette = 'flare')
plt.xlabel("Restaurant Name",size = 20)
plt.ylabel("Aggregate rating",size = 20)
plt.xticks(size = 15, rotation = 90)
plt.yticks(size = 15)
plt.title('Aggregated Ratings of Ice Cream Parlours', fontweight = 'bold', size = 20);

# %% [markdown]
# ## Observations:
#
# People choose to have their breakfast at Starbucks, get their fast food at Dunkin Donuts, and get their ice cream at Starbucks.

# %% [markdown]
# ## Conclusions:
# -The dataset is biassed in favour of India and does not encompass all restaurant data worldwide.
# -There are six categories used to rate restaurants.
# No Rating, Average, Good, Excellent
# -Although Connaught Palace has the most restaurants listed on Zomato in terms of accepted online delivery, Malviya Nagar and ---Defense Colony appear to be doing better.
# -The following cuisine seems to receive higher ratings at the best restaurants
# North Indian, Continental, Italian, Chinese.
# -Cost and rating have no relationship. On the other hand, some of the most well-liked restaurants are also some of the cheapest.
# Indian restaurants appear to do better than American restaurants at fast food chains and ice cream parlours, according to reviews of typical eateries.
